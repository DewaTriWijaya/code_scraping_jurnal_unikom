# %%
import pandas as pd 

df = pd.read_csv('Tabel Article Final Unikom.csv')
df
# Out:
#       id_works  id_sinta                             doi  \
# 0            1    257962       10.17509/ajsee.v1i3.33755
# 1            2   5985954         10.11591/eei.v10i6.3205
# 2            3   5985954       10.34010/jtk3ti.v4i1.5533
# 3            4   5985954  10.1109/icic54025.2021.9633001
# 4            5   5985954       10.34010/jtk3ti.v8i1.5594
# ...        ...       ...                             ...
# 4798      4812   6926655  10.11591/ijai.v11.i2.pp679-686
# 4799      4813   6926655      10.3844/jcssp.2023.251.260
# 4800      4814   6926655         10.36040/jati.v7i6.8205
# 4801      4815   6926655         10.36040/jati.v8i2.8242
# 4802      4816   6926655     10.21776/jeeccis.v18i2.1666
#
#                                                   title  \
# 0     Designing an Educational Website regarding Rec...
# 1     Prototype mobile contactless transaction syste...
# 2     Perencanaan Strategis Si/Ti Pada Disdikpora Ka...
# ...

# %%
# car nama dari id_sinta 6048499 tambah 
df_sinta = df[df['id_sinta'] == 6761166]
df_sinta
# Out:
#       id_works  id_sinta                          doi  \
# 3079      3091   6761166       10.34010/mhd.v1i1.4847
# 3080      3092   6761166  10.1101/2021.02.17.21251917
# 3081      3093   6761166  10.1136/bmjopen-2021-050303
# 3082      3094   6761166        10.4269/ajtmh.21-0737
# 3083      3095   6761166    10.53388/tmrcr20210522009
# ...        ...       ...                          ...
# 3628      3640   6761166  10.1007/978-981-95-3612-2_3
# 3629      3641   6761166     10.1093/ofid/ofaf695.892
# 3630      3642   6761166     10.1093/ofid/ofaf695.867
# 3631      3643   6761166  10.62383/mahkamah.v3i1.1447
# 3632      3644   6761166     10.1093/ofid/ofaf695.779
#
#                                                   title  \
# 3079  ANALISIS JUKUGO BERAKHIRAN ～代 (DAI) DAN ～料 (RY...
# 3080  What is the extent of COVID-19 vaccine hesitan...
# 3081  What is the extent of COVID-19 vaccine hesitan...
# 3082  Case Report: Home-based Management of Severe C...
# ...

# %%
# car nama dari id_sinta 6048499 tambah published tahun 2026
df_sinta = df[(df['id_sinta'] == 6761166) & (df['published'].str.contains('2026'))]
df_sinta
# Out:
#       id_works  id_sinta                          doi  \
# 3624      3636   6761166     10.53461/jujbr.v25i02.96
# 3625      3637   6761166           10.1002/ccr3.71806
# 3626      3638   6761166   10.1079/9781800628649.0007
# 3627      3639   6761166  10.9734/jpri/2026/v38i17801
# 3628      3640   6761166  10.1007/978-981-95-3612-2_3
# 3629      3641   6761166     10.1093/ofid/ofaf695.892
# 3630      3642   6761166     10.1093/ofid/ofaf695.867
# 3631      3643   6761166  10.62383/mahkamah.v3i1.1447
# 3632      3644   6761166     10.1093/ofid/ofaf695.779
#
#                                                   title  \
# 3624  The Role of Mobile Financial Services (MFSs) o...
# 3625  Continuous Passive Motion in the Rehabilitatio...
# 3626  Artificial Intelligence-Assisted Omics Techniq...
# 3627  Wound Healing Property of Saponins of Herbal D...
# 3628  Single-Cell Analysis and Cancer Research: Impl...
# 3629  P-679. Invasive pneumococcal pneumonia: is bac...
# ...

# %%
df_sinta = df[df['id_sinta'] == 6048499]
df_sinta
# Out:
#       id_works  id_sinta                               doi  \
# 4493      4507   6048499         10.29244/jmpi.2022.9.1.26
# 4494      4508   6048499          10.26656/fr.2017.7(s1).2
# 4495      4509   6048499          10.26656/fr.2017.7(s2).1
# 4496      4510   6048499  10.1109/citsm67730.2025.11291249
# 4497      4511   6048499       10.37339/jurpikat.v6i2.1912
#
#                                                   title  \
# 4493  Pengeringan Cabai Merah (Capsicum annuum L.) d...
# 4494  Application of ultrasound in germinated soybea...
# 4495  Effect of tempe protein isolates addition on b...
# 4496  The Effectiveness of AI-Based Educational Game...
# 4497  Pelatihan Pengelolaan Sampah Organik Rumah Tan...
#
#                                                 authors  \
# 4493  Harum Fadhilatunnur; Subarna; Zhofran Murtadho...
# 4494  A.P.G. Prayudani; W. Winarsih; Subarna; E. Sya...
# 4495  A.P.G. Prayudani; M. Astawan; G.M. Syani; Suba...
# ...

# %%
# coba value unique jurnal berdasarkan publisher  Universitas Komputer Indonesia
df_jurnal_unikom = df[df['publisher'] == 'Universitas Komputer Indonesia']
df_jurnal_unikom['journal_title'].unique()
# Out:
# array(['Jurnal Tata Kelola dan Kerangka Kerja Teknologi Informasi',
#        'Jurnal Agregasi : Aksi Reformasi Government dalam Demokrasi',
#        'Jurnal Ilmu Keuangan dan Perbankan (JIKA)',
#        'International Journal of Research and Applied Technology',
#        'Majalah Ilmiah UNIKOM',
#        'Proceeding of International Conference on Business, Economics, Social Sciences, and Humanities',
#        'Jurnal Penelitian Mahasiswa Teknik dan Ilmu Komputer (JUPITER)',
#        'Komputa : Jurnal Ilmiah Komputer dan Informatika',
#        'Journal of Economics, Management, Business and Accounting',
#        'Journal of Economics Management Business and Accounting',
#        'Indonesian Community Service and Empowerment Journal (IComSE)',
#        'Komputika : Jurnal Sistem Komputer', 'Jurnal Wilayah dan Kota',
#        'International Journal of Informatics, Information System and Computer Engineering (INJIISCOM)',
#        'Jurnal Riset Akuntansi',
# ...
