# %%
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\dewat\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\dewat\anaconda3\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\dewat\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dewat\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dewat\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dewat\anaconda3\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dewat\anaconda3\lib\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dewat\anaconda3\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dewat\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dewat\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dewat\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dewat\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\dewat\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

def debug_single_sinta(sinta_id):
    url = f"https://sinta.kemdiktisaintek.go.id/authors/profile/{sinta_id}/?view=scopus"
    headers = {
        "User-Agent": "Mozilla/5.0"
    }

    r = requests.get(url, headers=headers, timeout=30)
    print("Status Code:", r.status_code)

    soup = BeautifulSoup(r.text, "html.parser")

    articles = soup.select("div.ar-list-item")
    print("Jumlah artikel:", len(articles))
    print("-" * 50)

    for i, art in enumerate(articles, start=1):
        title = art.select_one("div.ar-title a")
        year = art.select_one("a.ar-year")
        cited = art.select_one("a.ar-cited")
        quartile = art.select_one("a.ar-quartile")
        journal = art.select_one("a.ar-pub")

        print(f"Artikel #{i}")
        print("Judul   :", title.text.strip() if title else "-")
        print("Tahun   :", year.text.strip() if year else "-")
        print("Cited   :", cited.text.strip() if cited else "-")
        print("Quartile:", quartile.text.strip() if quartile else "-")
        print("Jurnal  :", journal.text.strip() if journal else "-")
        print("-" * 50)

if __name__ == "__main__":
    debug_single_sinta(258567)
# Out:
# Status Code: 200
# Jumlah artikel: 4
# --------------------------------------------------
# Artikel #1
# Judul   : The Mediating Roles of Customer Trust and Satisfaction in E-Service Quality and the Repurchase Intention Relationship
# Tahun   : 2024
# Cited   : 3 cited
# Quartile: Q2 as Journal
# Jurnal  : Australasian Accounting Business and Finance Journal
# --------------------------------------------------
# Artikel #2
# Judul   : INVESTMENT PROMOTION STRATEGY OF TOURISM AND AGRICULTURE SECTOR TO PROMOTE REGIONAL COMPETITIVENESS
# Tahun   : 2023
# Cited   : 1 cited
# Quartile: Q2 as Journal
# Jurnal  : Journal of Eastern European and Central Asian Research
# --------------------------------------------------
# Artikel #3
# Judul   : THE STRATEGIC DEVELOPMENT OF MARITIME CONNECTIVITY IN THE BORDER AREA IN INDONESIA
# Tahun   : 2023
# Cited   : 2 cited
# Quartile: Q2 as Journal
# Jurnal  : Journal of Eastern European and Central Asian Research
# --------------------------------------------------
# Artikel #4
# Judul   : Supporting Food Self-Sufficiency to Increase the Economy of the Village
# Tahun   : 2019
# Cited   : 0 cited
# Quartile: Q3 as Conference Proceedin
# Jurnal  : Iop Conference Series Materials Science and Engineering
# --------------------------------------------------
