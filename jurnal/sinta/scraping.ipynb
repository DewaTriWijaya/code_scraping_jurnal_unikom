# %%
import re

def extract_cited(text):
    match = re.search(r"(\d+)\s*cited", text.lower())
    return int(match.group(1)) if match else None

# %%
def extract_doi(text, link=None):
    doi_pattern = r"(10\.\d{4,9}/[-._;()/:A-Z0-9]+)"
    if text:
        match = re.search(doi_pattern, text, re.I)
        if match:
            return match.group(1)
    if link and "doi.org" in link:
        return link.split("doi.org/")[-1]
    return None

# %%
def scrape_author(author_id):
    all_data = []

    for view, pub_type in VIEW_TYPE_MAP.items():
        url = f"{BASE_URL}/{author_id}/?view={view}"
        soup = BeautifulSoup(requests.get(url, headers=HEADERS).text, "html.parser")

        for item in soup.select("div.ar-list-item"):
            title_el = item.select_one("div.ar-title a")
            title = title_el.get_text(strip=True) if title_el else None
            link = title_el["href"] if title_el else None

            full_text = item.get_text(" ", strip=True)
            doi = extract_doi(full_text, link)

            cited = extract_cited(full_text)

            quartile = item.select_one("a.ar-quartile")
            quartile = quartile.get_text(strip=True) if quartile else None

            detail = None

            # ===== LOGIKA KHUSUS PER TYPE =====

            if pub_type == "research":
                detail = quartile     # pindahkan ke detail
                quartile = None

            if pub_type == "community_service":
                detail = quartile     # pindahkan ke detail
                quartile = None

            if pub_type == "article_garuda":
                # pastikan cited hanya angka
                cited = cited
                # DOI tetap terpisah
                doi = doi

            meta_links = [a.get_text(strip=True) for a in item.select("div.ar-meta a")]

            data = {
                "author_id": author_id,
                "type": pub_type,
                "title": title,
                "detail": detail,
                "doi": doi,
                "year": item.select_one("a.ar-year").get_text(strip=True) if item.select_one("a.ar-year") else None,
                "quartile": quartile,
                "publisher": item.select_one("a.ar-pub").get_text(strip=True) if item.select_one("a.ar-pub") else None,
                "cited": cited,
                "author_order": next((t for t in meta_links if "Author Order" in t), None),
                "creator": next((t for t in meta_links if "Creator" in t), None),
                "source_link": link
            }

            all_data.append(data)

    return all_data

# %%
import pandas as pd

data = scrape_author(258671)
df = pd.DataFrame(data)
print(df.head())

# %%
df
# Out:
#     author_id               type  \
# 0      258671     article_scopus
# 1      258671     article_scopus
# 2      258671     article_scopus
# 3      258671     article_scopus
# 4      258671     article_scopus
# 5      258671     article_scopus
# 6      258671     article_scopus
# 7      258671     article_scopus
# 8      258671     article_garuda
# 9      258671     article_garuda
# 10     258671     article_garuda
# 11     258671     article_garuda
# 12     258671     article_garuda
# 13     258671     article_garuda
# 14     258671     article_garuda
# 15     258671     article_garuda
# 16     258671     article_garuda
# 17     258671   article_gscholar
# 18     258671   article_gscholar
# 19     258671   article_gscholar
# 20     258671   article_gscholar
# 21     258671   article_gscholar
# 22     258671   article_gscholar
# 23     258671   article_gscholar
# 24     258671   article_gscholar
# 25     258671   article_gscholar
# 26     258671   article_gscholar
# 27     258671           research
# 28     258671           research
# 29     258671           research
# 30     258671           research
# 31     258671           research
# 32     258671  community_service
# 33     258671  community_service
# 34     258671               iprs
# 35     258671               iprs
# 36     258671               iprs
# 37     258671               iprs
# 38     258671               iprs
# 39     258671               iprs
# 40     258671               iprs
# 41     258671               iprs
# 42     258671               iprs
# 43     258671               iprs
#
#                                                 title          detail  \
# 0   Virtual reality photography tour 360 degree pa...            None
# 1   Utilization of Context Aware System: Enhancing...            None
# 2   Augmented Reality Based Indoor Navigation Syst...            None
# 3   An Augmented Reality-Based Application for Foo...            None
# 4   An augmented reality-based lipstick color reco...            None
# 5   Relay Streaming System Model to Social Media P...            None
# 6   Implementation of Web Assembly Technology as V...            None
# 7   Implementation of Visual, Auditory, Kineshthet...            None
# 8   Pengelompokan Mahasiswa Berdasarkan Capaian Pe...            None
# 9   Pemberdayaan Masyarakat Desa Rancabango melalu...            None
# 10  Pembangunan Game Edukasi Interaktif Pelajaran ...            None
# 11  Introduksi dan Pelatihan Learning Management S...            None
# 12  PURWARUPA SISTEM E-VOTING MENGGUNAKAN ENKRIPSI...            None
# 13  Pelatihan Pembuatan Media Pembelajaran Di PGRI...            None
# 14  PEMBANGUNAN PROTOTYPE APLIKASI PENGAWASAN DAN ...            None
# 15  PEMBANGUNAN APLIKASI PERENCANAAN PERJALANAN BA...            None
# 16  PERANCANGAN BLUEPRINT KNOWLEDGE MANAGEMENT SYS...            None
# 17  Pengelompokan Mahasiswa Berdasarkan Capaian Pe...            None
# 18  Pemberdayaan Masyarakat Desa Rancabango melalu...            None
# 19  Virtual reality photography tour 360 degree pa...            None
# 20  Pembangunan Game Edukasi Interaktif Pelajaran ...            None
# 21  KAWANKULINER: PERSONALISED FOOD RECOMMENDATION...            None
# 22  Introduksi dan Pelatihan Learning Management S...            None
# 23  Utilization of Context Aware System: Enhancing...            None
# 24  Augmented Reality Based Indoor Navigation Syst...            None
# 25  An augmented reality-based lipstick color reco...            None
# 26  Pelatihan dan penerapan IoT smart farming hidr...            None
# 27  PENGEMBANGAN SISTEM REKOMENDASI PROFESI BERDAS...   Rp. 6.000.000
# 28  VIRTUAL REALITY PHOTOGRAPHY TOUR 360 DEGREE PA...   Rp. 2.500.000
# 29  RELAY STREAMING SYSTEM MODEL TO SOCIAL MEDIA P...   Rp. 2.500.000
# 30  IMPLEMENTATION OF WEB ASSEMBLY TECHNOLOGY AS V...   Rp. 2.500.000
# 31  PENERAPAN METODE ANALYTICAL HIERARCHY PROCESS ...  Rp. 15.900.000
# 32  PELATIHAN LEARNING MANAGEMENT SYSTEM SEBAGAI M...   Rp. 2.000.000
# 33  POTENTIAL AGRICULTURAL LAND SUITABILTY VISUALI...  Rp. 33.006.700
# 34  Sistem Pencatatan Data Koleksi Sejarah Di Muse...            None
# 35  Aplikasi Pelatihan Pengucapan Huruf Hijaiyah U...            None
# 6   Iop Conference Series Materials Science and En...    1.0
# 7   Iop Conference Series Materials Science and En...    3.0
# 8   Komputa : Jurnal Ilmiah Komputer dan Informati...    NaN
# 9   Jurnal Pengabdian Teknik dan Ilmu Komputer (Pe...    NaN
# 10  Komputa : Jurnal Ilmiah Komputer dan Informati...    NaN
# 11  Jurnal Pengabdian Masyarakat Progresif Humanis...    NaN
# 12  Jurnal Penelitian Mahasiswa Teknik dan Ilmu Ko...    NaN
# 13  Indonesian Community Service and Empowerment J...    NaN
# 14  Komputa : Jurnal Ilmiah Komputer dan Informati...    NaN
# 15  Majalah Ilmiah UNIKOM Vol. 16 No. 2 (2018): Ma...    NaN
# 16  Komputa : Jurnal Ilmiah Komputer dan Informati...    NaN
# 17  Komputa: Jurnal Ilmiah Komputer dan Informatik...    0.0
# 18  Jurnal Pengabdian Teknik dan Ilmu Komputer (Pe...    0.0
# 19  AIP Conference Proceedings 3200 (1), 040017, 2025    0.0
# 20  Komputa: Jurnal Ilmiah Komputer dan Informatik...    0.0
# 21  Journal of Mathematical Sciences and Informati...    1.0
# 22  J. Pengabdi. Masy. Progresif Humanis Brainstor...    9.0
# 23  2024 International Conference on Informatics E...    0.0
# 24  2024 International Conference on Informatics E...    0.0
# 25  AIP Conference Proceedings 2510 (1), 030028, 2023    1.0
# 26  Dinamisia: Jurnal Pengabdian Kepada Masyarakat...   20.0
# 27                         PENELITIAN INTERNAL ( PD )    NaN
# 28       PENELITIAN SEMINAR & PUBLIKASI ILMIAH ( SI )    NaN
# 29       PENELITIAN SEMINAR & PUBLIKASI ILMIAH ( SI )    NaN
# 30     PENELITIAN SEMINAR ILMIAH DAN PUBLIKASI ( SI )    NaN
# 31  Penelitian Kompetitif Nasional ( PDP/Dosen Pem...    NaN
# 32  PROGRAM PENGABDIAN DAN PEMBERDAYAAN MASYARAKAT...    NaN
# 33  PROGRAM PENGABDIAN DAN PEMBERDAYAAN MASYARAKAT...    NaN
# 34                     Universitas Komputer Indonesia    NaN
# 35                     Universitas Komputer Indonesia    NaN
# 36                     Universitas Komputer Indonesia    NaN
# 37                     Universitas Komputer Indonesia    NaN
# 38               Richi Dwi Agustia dan Hanhan Maulana    NaN
# 39                     Universitas Komputer Indonesia    NaN
# 40                     Universitas Komputer Indonesia    NaN
# 41                     Universitas Komputer Indonesia    NaN
# 42                     Universitas Komputer Indonesia    NaN
# 43                     Universitas Komputer Indonesia    NaN
#
#              author_order                 creator  \
# 0   Author Order : 1 of 2  Creator : Agustia R.D.
# 1   Author Order : 4 of 4     Creator : Maulaa H.
# 2   Author Order : 1 of 3  Creator : Agustia R.D.
# 3   Author Order : 1 of 2    Creator : Agustia R.
# 4   Author Order : 1 of 2  Creator : Agustia R.D.
# 5   Author Order : 1 of 2  Creator : Agustia R.D.
