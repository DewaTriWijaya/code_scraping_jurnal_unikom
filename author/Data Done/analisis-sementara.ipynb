# %%
import pandas as pd
df = pd.read_csv('Tabel Authors Final Unikom.csv')

# %%
# cari nama ANGGA SETIYADI
result = df[df['fullname'].str.contains('MOHAMMAD ALI', na=False)]
result
# Out:
#          fullname  id_sinta        nidn degree          major  \
# 135  MOHAMMAD ALI   6761166  0410059105     S1  Sastra Jepang
#
#              faculty  sinta_score_overall  sinta_score_3yr  affil_score  \
# 135  Fakultas Sastra                  397              130          397
#
#      affil_score_3yr  ... s_cited_document_scopus  s_h-index_scopus  \
# 135              130  ...                       0                 0
#
#      s_i10_index_scopus  s_g-index_scopus  s_article_gscholar  \
# 135                   0                 1                  56
#
#      s_citation_gscholar  s_cited_document_gscholar  s_h-index_gscholar  \
# 135                   64                         21                   4
#
#      s_i10_index_gscholar  s_g-index_gscholar
# 135                     1                   2
#
# [1 rows x 23 columns]

# %%
# cari nama anggota berdasarkan id_sinta
result_id_sinta = df[df['id_sinta'] == 258729]  # Ganti 123456 dengan id_sinta yang diinginkan
result_id_sinta
# Out:
#                      fullname  id_sinta        nidn degree            major  \
# 133  MOCHAMAD FAJAR WICAKSONO    258729  0416098601     D3  Teknik Komputer
#
#                                faculty  sinta_score_overall  sinta_score_3yr  \
# 133  Fakultas Teknik dan Ilmu Komputer                  982              163
#
#      affil_score  affil_score_3yr  ... s_cited_document_scopus  \
# 133          982              163  ...                       9
#
#      s_h-index_scopus  s_i10_index_scopus  s_g-index_scopus  \
# 133                 2                   0                 1
#
#      s_article_gscholar  s_citation_gscholar  s_cited_document_gscholar  \
# 133                  90                  932                         52
#
#      s_h-index_gscholar  s_i10_index_gscholar  s_g-index_gscholar
# 133                  12                    15                   1
#
# [1 rows x 23 columns]
